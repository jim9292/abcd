# %% [markdown]
# <a href="https://colab.research.google.com/github/jim9292/abcd/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/leela-zero/leela-zero
# !cd /content/leela-zero/training/tf
# Out:
# Cloning into 'leela-zero'...
# remote: Enumerating objects: 4919, done.
# remote: Total 4919 (delta 0), reused 0 (delta 0), pack-reused 4919
# Receiving objects: 100% (4919/4919), 3.53 MiB | 21.66 MiB/s, done.
# Resolving deltas: 100% (3538/3538), done.

# %%
cd /content/leela-zero/training/tf

# %%
# !curl -O https://leela.online-go.com/training/train_a20c31da.zip
# !unzip train_a20c31da.zip
# !curl -O https://leela.online-go.com/networks/a20c31da0db23da6efc16739b2e62b058b2ff86060512c58ef6fefe14a0e2a82.gz
# !gzip -d a20c31da0db23da6efc16739b2e62b058b2ff86060512c58ef6fefe14a0e2a82.gz

# %%
ls

# %%
# !rm tfprocess.py

# %%
zip /content/leela-zero/training/tf/12*.txt
# Out:
# 	zip warning: missing end signature--probably not a zip file (did you
# 	zip warning: remember to use binary mode when you transferred it?)
# 	zip warning: (if you are trying to read a damaged archive try -F)
#
# zip error: Zip file structure invalid (/content/leela-zero/training/tf/123.txt)

# %%
# !mkdir /content/leela-zero/training/tf/lzw

# %%
ls
# Out:
# 123.txt
# a20c31da0db23da6efc16739b2e62b058b2ff86060512c58ef6fefe14a0e2a82
# average_weights.py*
# checkpoint
# chunkparser.py
# dumper/
# leelalogs/
# leelaz-model-0.data-00000-of-00001
# leelaz-model-0.index
# leelaz-model-0.meta
# lz.py
# lzw/
# mixprec.py
# net2net.py*
# net_to_model.py*
# __pycache__/
# quantize_weights.py*
# requirements.txt
# shufflebuffer.py
# tfprocess.py
# train_a20c31da_0.gz
# train_a20c31da_1000.gz
# train_a20c31da_1001.gz
# train_a20c31da_1002.gz
# train_a20c31da_1003.gz
# train_a20c31da_1004.gz
# train_a20c31da_1005.gz
# train_a20c31da_1006.gz
# train_a20c31da_1007.gz
# train_a20c31da_1008.gz
# train_a20c31da_1009.gz
# train_a20c31da_100.gz
# train_a20c31da_1010.gz
# train_a20c31da_1011.gz
# train_a20c31da_1012.gz
# train_a20c31da_1013.gz
# train_a20c31da_1014.gz
# train_a20c31da_1015.gz
# train_a20c31da_1016.gz
# train_a20c31da_1017.gz
# train_a20c31da_1018.gz
# train_a20c31da_1019.gz
# train_a20c31da_101.gz
# train_a20c31da_1020.gz
# ...

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4ca32799-696a-4c6e-bcf3-e32e486b3582" name="files[]" multiple disabled />
#      <output id="result-4ca32799-696a-4c6e-bcf3-e32e486b3582">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tfprocess.py to tfprocess.py
# User uploaded file "tfprocess.py" with length 30374 bytes

# %%
# !python net_to_model.py a20c31da0db23da6efc16739b2e62b058b2ff86060512c58ef6fefe14a0e2a82
# Out:
# Version 1
# Channels 256
# Blocks 40
# 2019-06-01 01:11:16.873896: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-01 01:11:16.874392: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2f4db80 executing computations on platform Host. Devices:
# 2019-06-01 01:11:16.874435: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-01 01:11:17.162674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-01 01:11:17.163365: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2f4d340 executing computations on platform CUDA. Devices:
# 2019-06-01 01:11:17.163398: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...

# %%
# !python parse.py 40 256 train_a20c31da_
# Out:
# Training with 4402 chunks, validating on 489 chunks
# Using 1 worker processes.
# Using 1 worker processes.
# 2019-06-01 04:13:50.965622: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-06-01 04:13:50.966081: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2792c60 executing computations on platform Host. Devices:
# 2019-06-01 04:13:50.966128: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-06-01 04:13:51.376038: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-01 04:13:51.376644: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2793340 executing computations on platform CUDA. Devices:
# ...

# %%
files.download('')
